# %%
# !pip install pdfplumber
# !pip install docx
# !pip install docx2txt
# !pip install gradio
# !pip install transformers
# !pip install torch
# !pip install accelerate
# !pip install sentencepiece
# !pip install torch
# !pip install pypdf
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.8 MB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from pdfplumber) (10.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /home/sayantan/.local/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.2 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.6 MB/s eta 0:00:0000:01:00:01
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 48.5 MB/s eta 0:00:00:00:01
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /home/sayantan/.local/lib/python3.11/site-packages (from docx) (5.2.2)
# Requirement already satisfied: Pillow>=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from docx) (10.3.0)
# Building wheels for collected packages: docx
#   Building wheel for docx (setup.py) ... done
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53895 sha256=978211a15a7c2d6cfa14aaccfff7da2c17185e89051ea1e48cf48fc040a932c0
#   Stored in directory: /drive/sayantan/.cache/pip/wheels/c1/3e/c3/e81c11effd0be5658a035947c66792dd993bcff317eae0e1ed
# Successfully built docx
# Installing collected packages: docx
# Successfully installed docx-0.2.4
# Requirement already satisfied: docx2txt in /home/sayantan/.local/lib/python3.11/site-packages (0.8)
# Requirement already satisfied: gradio in /home/sayantan/.local/lib/python3.11/site-packages (4.37.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.112.2)
# Requirement already satisfied: ffmpy in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==1.0.2 in /home/sayantan/.local/lib/python3.11/site-packages (from gradio) (1.0.2)
# Requirement already satisfied: httpx>=0.24.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (3.9.0)
# Requirement already satisfied: numpy<3.0,>=1.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (24.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.4.8)
# Requirement already satisfied: semantic-version~=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (0.12.0)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio) (2.2.1)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio-client==1.0.2->gradio) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from gradio-client==1.0.2->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio) (4.22.0)
# Requirement already satisfied: toolz in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (4.4.0)
# Requirement already satisfied: certifi in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-13.8.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from fastapi->gradio) (0.38.4)
# Requirement already satisfied: attrs>=22.2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: six>=1.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading orjson-3.10.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 5.6 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.7 MB/s eta 0:00:00
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.7 MB/s eta 0:00:00
# Downloading rich-13.8.0-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 kB 10.6 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.6 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: uvicorn, shellingham, python-multipart, orjson, mdurl, markdown-it-py, rich, typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
#   WARNING: Failed to remove contents in a temporary directory '/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/~yper-0.9.4.dist-info'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/~yper'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.5 which is incompatible.
# spacy 3.7.2 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.5 which is incompatible.
# Successfully installed markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.10.7 python-multipart-0.0.9 rich-13.8.0 shellingham-1.5.4 typer uvicorn-0.30.6
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Requirement already satisfied: transformers in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (4.42.4)
# Requirement already satisfied: filelock in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy<2.0,>=1.17 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->transformers) (2024.7.4)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Requirement already satisfied: torch in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: filelock in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2.8.8)
# Requirement already satisfied: jinja2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Requirement already satisfied: accelerate in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (0.30.1)
# Requirement already satisfied: numpy>=1.17 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (0.23.2)
# Requirement already satisfied: safetensors>=0.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.8.8)
# Requirement already satisfied: jinja2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Requirement already satisfied: sentencepiece in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (0.2.0)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Requirement already satisfied: torch in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: filelock in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2.8.8)
# Requirement already satisfied: jinja2 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /root/miniconda3/envs/abhishek/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Collecting pypdf
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 9.5 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# Installing collected packages: pypdf
# Successfully installed pypdf-4.3.1
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~yper (/root/miniconda3/envs/abhishek/lib/python3.11/site-packages)

# %%
import gradio as gr
import pdfplumber
import docx2txt
import os
import re
import torch
import csv
import sys
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the model and tokenizer
model_name = "microsoft/Phi-3.5-mini-instruct"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float32,
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Create a text generation pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file using pdfplumber."""
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() + "\n"
    return text

def extract_text_from_docx(docx_path):
    """Extract text from a DOCX file using docx2txt."""
    text = docx2txt.process(docx_path)
    return text

def extract_resume_info(text):
    """Extract key information from the resume text."""
    print("Extracting resume information...")
    text = text.lower()
    headers = {
        'name': 'NAME',
        'skills': 'SKILLS',
        'experience': 'EXPERIENCE',
        'education': 'EDUCATION'
    }
    first_line = text.split('\n', 1)[0].strip()
    name_match = re.match(r'^.*\s*name\s*[:\-]?\s*(.*)', first_line, re.IGNORECASE)
    name = name_match.group(1).strip() if name_match else first_line
    print(f"Extracted Name: {name}")

    for key, value in headers.items():
        text = re.sub(rf'\b{key}\b', value, text, flags=re.IGNORECASE)

    def extract_section(header):
        pattern = rf'\b{header}\b\s*[:\-]?\s*(.*?)(?=\n[A-Z]|$)'
        match = re.search(pattern, text, re.DOTALL)
        result = match.group(1).strip() if match else 'Not Found'
        print(f"Extracted {header}: {result}")
        return result

    skills = extract_section('SKILLS')
    experience = extract_section('EXPERIENCE')
    education = extract_section('EDUCATION')

    # Ensure experience is treated as an integer for comparison
    experience_present = 1 if experience != 'Not Found' else 0
    return name, skills, experience_present, education

def generate_response(prompt):
    """Generate a response using the language model."""
    print(f"Generating response for prompt: {prompt}")
    generation_args = {
        "max_new_tokens": 90,
        "return_full_text": True,
        "temperature": 0.7,
        "do_sample": True,
    }
    output = pipe(prompt, **generation_args)
    generated_text = output[0]['generated_text'].strip()

    # Find all questions that start with a number or with "Question:"
    questions = re.findall(r'(?:\d+\.|\b[qQ]uestion:).*?\?', generated_text)

    print(f"Generated Text: {generated_text}")

    # Return the last question if any, otherwise return a default message
    return questions[-1] if questions else "No relevant question generated."

def generate_response_for_df(df):
    """Generate model responses for each question in the DataFrame."""
    # List to store model responses
    model_responses = []
    
    for i, row in df.iterrows():
        question = row['question']
        print(f"Generating response for question: {question}")
        
        # Generate a response using the existing generate_response logic
        generation_args = {
            "max_new_tokens": 90,
            "return_full_text": True,
            "temperature": 0.7,
            "do_sample": True,
        }
        output = pipe(question, **generation_args)
        generated_text = output[0]['generated_text'].strip()
        
        # Directly use the generated response
        model_response = generated_text
        
        print(f"Model Response: {model_response}")
        model_responses.append(model_response)
    
    # Add the generated model responses to the DataFrame
    df['model_response'] = model_responses
    return df
def calculate_similarity(df):
    """Calculate similarity between user and model responses and return updated DataFrame."""
    # Initialize TF-IDF Vectorizer
    vectorizer = TfidfVectorizer()
    
    similarity_scores = []
    
    for i, row in df.iterrows():
        user_response = row['user_response']
        model_response = row['model_response']
        
        # Compute TF-IDF for the user response and model response
        tfidf_matrix = vectorizer.fit_transform([user_response, model_response])
        
        # Calculate cosine similarity between user and model response
        similarity = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
        
        # Convert similarity to percentage
        similarity_percentage = round(similarity * 100, 2)
        
        print(f"Similarity score for row {i}: {similarity_percentage}%")
        similarity_scores.append(similarity_percentage)
    
    # Add the similarity scores to the DataFrame
    df['similarity'] = similarity_scores
    return df

def process_resume(file_path):
    """Process the resume to extract text and key information."""
    print(f"Processing resume file: {file_path}")
    file_extension = os.path.splitext(file_path)[1].lower()
    if file_extension == '.pdf':
        extracted_text = extract_text_from_pdf(file_path)
    elif file_extension == '.docx':
        extracted_text = extract_text_from_docx(file_path)
    else:
        raise ValueError("Unsupported file format. Please upload a PDF or DOCX file.")
    print(f"Extracted Text: {extracted_text[:200]}...")  # Show a snippet of the extracted text
    return extracted_text

import pandas as pd

def run_interview(name, skills, experience, user_response=None, questions_and_answers=None, user=None, stage=0):
    """Conduct an interview based on the extracted resume data."""
    if questions_and_answers is None:
        questions_and_answers = []
    if user is None:
        user = []


    print(f"Stage: {stage}")
    print(f"User Response: {user_response}")
    print(questions_and_answers)
    print("User", user)

    if experience and skills:
        if stage == 0:
            print("step: 0")
            experience_question = "Can you describe a challenging project where you applied your experience?"
            questions_and_answers.append([experience_question, ""])
            print(f"Stage 0: Added experience question: {experience_question}")
            stage += 1

        elif stage == 1 and user_response:
            print("step: 1")
            user.append(user_response)
            print(user)
            prompt = f"You are a job interviewer. Please generate only 1 follow-up question starting with 'Question:' WITHOUT any additional text or answer...just the question.. based on this: {user_response}"
            follow_up_question = generate_response(prompt)
            questions_and_answers.append([follow_up_question, ""])
            print(f"Stage 1: Added follow-up question: {follow_up_question}")
            stage += 1

        elif stage == 2 and user_response:
            # Ensure questions_and_answers is empty at the beginning of stage 2
                print ("step2_1")
                user.append(user_response)
                prompt_for_questions = f"Generate 1 interview questions based on the following skills: {skills}. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text."
                generated_question = generate_response(prompt_for_questions)
                questions_and_answers.append([generated_question,""])
                stage += 1
        elif stage == 3 and user_response:
                print ("step3")
                user.append(user_response)
                prompt_for_questions = f"Generate 1 interview questions based on the following skills: {skills} not this question {questions_and_answers[-1][0]}. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text."
                generated_question = generate_response(prompt_for_questions)
                questions_and_answers.append([generated_question,""])
                stage += 1
        elif stage == 4 and user_response:
                print ("step4")
                user.append(user_response)
                prompt_for_questions = f"Generate 1 interview questions based on the following skills: {skills} not this question {questions_and_answers[-1][0]}. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text."
                generated_question = generate_response(prompt_for_questions)
                questions_and_answers.append([generated_question,""])
                stage += 1
        elif stage == 5 and user_response:
                print ("step5")
                user.append(user_response)
                prompt_for_questions = f"Generate 1 interview questions based on the following skills: {skills} not this question {questions_and_answers[-1][0]}. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text."
                generated_question = generate_response(prompt_for_questions)
                questions_and_answers.append([generated_question,""])
                stage += 1

        elif stage == 6 and user_response:
            print("Stage 6: Adding user responses and updating stage...")
            user.append(user_response)
            print("user response1", user)
            print("q nd a", questions_and_answers)
            print("user response2", user)
            questions_and_answers = [q[0] for q in questions_and_answers]

            # Create DataFrame
            df = pd.DataFrame({
                'question': questions_and_answers,
                'user_response': user
            })
            # df = pd.DataFrame(questions_and_answers, columns=["Question", "User_Response"])
            df = df.drop(index=[0, 1])
            df= generate_response_for_df(df)
            df=calculate_similarity(df)
            df.to_csv("skills_interview_results.csv", index=False)
            print(f"DataFrame saved to CSV.")
            questions_and_answers.append(["Ok, got it... Thanks for taking the interview!! Have a great day!! ", ""])
            # print("Exitting")
            # sys.exit("Stopping the script")
            stage += 1

        # elif stage == 7:
        #     print("Stage 7: Saving skills-related Q&A to CSV...")
        #     df = pd.DataFrame(questions_and_answers, columns=["Question", "User Response"])
        #     df.to_csv("skills_interview_results.csv", index=False)
        #     print(f"DataFrame saved to CSV.")

        #     # Resetting the state
        #     questions_and_answers = []
        #     print("Exitting")
        #     sys.exit("Stopping the script")
        #     stage += 1

    # Return only the most recent question for display and the updated stage
    recent_question = questions_and_answers[-1][0] if questions_and_answers else ""
    print(f"Returning recent question: {recent_question}")
    return recent_question, stage, questions_and_answers,user


def upload_resume(file_path):
    """Upload and process the resume to extract key information."""
    print(f"Uploading resume file: {file_path}")
    resume_text = process_resume(file_path)
    name, skills, experience, education = extract_resume_info(resume_text)
    return name, skills, experience, education, resume_text

def interview_interface(name, skills, experience, user_response=None,stage=0, questions_and_answers=None, user= None):
    recent_question, new_stage, updated_questions_and_answers, updated_user = run_interview(name, skills, experience, user_response, questions_and_answers, user, stage)
    return recent_question, new_stage, updated_questions_and_answers, updated_user

def start_interview_from_file(file):
    """Extract resume info and automatically start the interview."""
    name, skills, experience, education, _ = upload_resume(file.name)
    return interview_interface(name, skills, experience, stage=0, questions_and_answers=[], user=[])

with gr.Blocks() as demo:
    with gr.Tabs():
        with gr.TabItem("Upload Resume"):
            resume_file = gr.File(label="Upload your resume (PDF or DOCX):")
            name_output = gr.Textbox(label="Name", interactive=False)
            skills_output = gr.Textbox(label="Skills", interactive=False)
            experience_output = gr.Textbox(label="Experience", interactive=False)
            education_output = gr.Textbox(label="Education", interactive=False)
            process_button = gr.Button("Process Resume")
            process_button.click(upload_resume, inputs=resume_file, outputs=[name_output, skills_output, experience_output, education_output])

        with gr.TabItem("Interview"):
            recent_question_output = gr.Textbox(label="Colloquium says", interactive=False)
            user_response_input = gr.Textbox(label="What do you think")
            submit_response_button = gr.Button("Answer now")

            # Initialize interview state and questions list
            stage = gr.State(value=0)
            questions_and_answers = gr.State(value=[])
            user = gr.State(value=[])
            # Automatically start interview when the resume is processed
            resume_file.change(start_interview_from_file, inputs=resume_file, outputs=[recent_question_output, stage, questions_and_answers, user])

            # Capture user response, generate model response, and update stage
            submit_response_button.click(
                interview_interface,
                inputs=[name_output, skills_output, experience_output, user_response_input, stage, questions_and_answers, user],
                outputs=[recent_question_output, stage, questions_and_answers, user]
            )

demo.launch(debug ='True', share='True')
# Out:
# 2024-09-08 22:05:18.260437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-08 22:05:18.273089: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-08 22:05:18.276911: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-08 22:05:18.286459: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-08 22:05:19.035763: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://e38af6ca49e6b18dea.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e38af6ca49e6b18dea.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Uploading resume file: /tmp/gradio/19dda12e8ee13f1ac7412d03d23e363940269eb2/resume.pdf
# Processing resume file: /tmp/gradio/19dda12e8ee13f1ac7412d03d23e363940269eb2/resume.pdf
# Extracted Text: Kumar Pallav
#    
# EDUCATION
# Indian Institute of Technology, Bombay
# Mumbai, India
# Bachelor of Computer Science and Engineering (with Hons.); Jun 2010 - May
# 2014
# CGPA 8.6/10
# EXPERIENCE
# Microsoft
# Redm...
# Extracting resume information...
# Extracted Name: kumar pallav
# Extracted SKILLS: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#  
# Extracted EXPERIENCE: microsoft
# redmond, wa
# software engineer, onenote jun 2016 - present
# modern hierarchy sync c++ nodejs
# worked on a new sync platform which would load notebook structure
# and hierarchy faster than the current state of the art. implemented client
# side representation of this hierarchy, derived from existing
# representation. added functionality to be able use the new
# representation without the need of resetting cache or reloading the
# notebook. built a small tool to visualize and debug this new
# representation.
# notebook cloud migration c++ c\#
# componentized native code from onenote desktop app to convert local
# onenote notebooks to cloud compatible notebooks. this was used in the
# new sharepoint migration tool.
# magic ink lookup and whiteboard app c++ c\#
# worked on recognizing ink strokes into words (using onboard ia) and
# recognizing keywords/entities given the context (using custom entity
# recognition service). implemented accumulation of images and
# interactive widgets (from various online sources) related to the keyword,
# to be inserted onto whiteboard canvas. implemented sharing EXPERIENCE
# for the new collaboration focused whiteboard app which included
# creating and joining a shared session.
# content addins c++ nodejs
# implemented content addins, for onenote desktop app, as small
# embedded web apps that would get hosted within managed webview
# controls. created their persistence model and rendering on the desktop
# app.
# microsoft
# vancouver, canada
# software engineer, onenote nov 2014 - may 2016
# embedded videos and web content c++ c\#
# worked on adding ability on onenote to host web content, making sure
# it is backwards compatible. implemented features to make handling and
# editing web content on the onenote page easier. added support for this
# feature on onenote web app.
# merged cells for tables c++ c\#
# added support for spanned cells for tables in onenote, keeping in mind
# backwards compatibility. implemented these capabilities in onenote web
# app.
# realtime ink c++ c\#
# as a ramp up project, prototyped ink collaboration using signalr web-
# sockets. worked on experimenting load and delay with multiple inputs in
# realtime.
# oracle bangalore, india
# software engineering intern, apps for enterprises may 2013 - july 2013
# containerization of ios apps objective-c c
# worked on sand-boxing of enterprise applications (containerization),
# enabling their installation on employee's ios devices, without worrying
# about security concerns. implemented wrapping of library function calls
# using swizzling, objective-c backend, linker flags and dynamic library
# injection.
# sandboxed browser app objective-c
# built a demo browser application for ios. containerized the app using
# the custom script, for it to work only for whitelisted urls.
# projects
# course allotment simulation using sat solver c++ minisat glucose
# as part of bachelors project, worked on solving the real world problem of finding a
# best course allocation under various constraints as a sat (satisfiability) problem and
# infer effects of different policies on course allotment and choices. studied relative
# efficiency of various heuristics modeled on different solvers like minisat and
# glucose.
# iit bombay hospital digitization java mysql
# created a complete web application in java that could handle operations on
# relational mysql databases to handle various processes of the university hospital.
# simple 2d physics engine c++
# wrote a physics engine for simple round bodies providing a back-end that could
# generate coordinates in real-time with collision, gravity, restitution and custom
# resolution of time.
# social sea php html javascript
# create a lightweight social search engine that shows the results ranked (using page-
# ranking) according to one's peer-group search history and rating.
# Extracted EDUCATION: indian institute of technology, bombay
# mumbai, india
# bachelor of computer science and engineering (with hons.); jun 2010 - may
# 2014
# cgpa 8.6/10
# Stage: 0
# User Response: None
# []
# User []
# step: 0
# Stage 0: Added experience question: Can you describe a challenging project where you applied your experience?
# Returning recent question: Can you describe a challenging project where you applied your experience?
# Uploading resume file: /tmp/gradio/19dda12e8ee13f1ac7412d03d23e363940269eb2/resume.pdf
# Processing resume file: /tmp/gradio/19dda12e8ee13f1ac7412d03d23e363940269eb2/resume.pdf
# Extracted Text: Kumar Pallav
#    
# EDUCATION
# Indian Institute of Technology, Bombay
# Mumbai, India
# Bachelor of Computer Science and Engineering (with Hons.); Jun 2010 - May
# 2014
# CGPA 8.6/10
# EXPERIENCE
# Microsoft
# Redm...
# Extracting resume information...
# Extracted Name: kumar pallav
# Extracted SKILLS: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#  
# Extracted EXPERIENCE: microsoft
# redmond, wa
# software engineer, onenote jun 2016 - present
# modern hierarchy sync c++ nodejs
# worked on a new sync platform which would load notebook structure
# and hierarchy faster than the current state of the art. implemented client
# side representation of this hierarchy, derived from existing
# representation. added functionality to be able use the new
# representation without the need of resetting cache or reloading the
# notebook. built a small tool to visualize and debug this new
# representation.
# notebook cloud migration c++ c\#
# componentized native code from onenote desktop app to convert local
# onenote notebooks to cloud compatible notebooks. this was used in the
# new sharepoint migration tool.
# magic ink lookup and whiteboard app c++ c\#
# worked on recognizing ink strokes into words (using onboard ia) and
# recognizing keywords/entities given the context (using custom entity
# recognition service). implemented accumulation of images and
# interactive widgets (from various online sources) related to the keyword,
# to be inserted onto whiteboard canvas. implemented sharing EXPERIENCE
# for the new collaboration focused whiteboard app which included
# creating and joining a shared session.
# content addins c++ nodejs
# implemented content addins, for onenote desktop app, as small
# embedded web apps that would get hosted within managed webview
# controls. created their persistence model and rendering on the desktop
# app.
# microsoft
# vancouver, canada
# software engineer, onenote nov 2014 - may 2016
# embedded videos and web content c++ c\#
# worked on adding ability on onenote to host web content, making sure
# it is backwards compatible. implemented features to make handling and
# editing web content on the onenote page easier. added support for this
# feature on onenote web app.
# merged cells for tables c++ c\#
# added support for spanned cells for tables in onenote, keeping in mind
# backwards compatibility. implemented these capabilities in onenote web
# app.
# realtime ink c++ c\#
# as a ramp up project, prototyped ink collaboration using signalr web-
# sockets. worked on experimenting load and delay with multiple inputs in
# realtime.
# oracle bangalore, india
# software engineering intern, apps for enterprises may 2013 - july 2013
# containerization of ios apps objective-c c
# worked on sand-boxing of enterprise applications (containerization),
# enabling their installation on employee's ios devices, without worrying
# about security concerns. implemented wrapping of library function calls
# using swizzling, objective-c backend, linker flags and dynamic library
# injection.
# sandboxed browser app objective-c
# built a demo browser application for ios. containerized the app using
# the custom script, for it to work only for whitelisted urls.
# projects
# course allotment simulation using sat solver c++ minisat glucose
# as part of bachelors project, worked on solving the real world problem of finding a
# best course allocation under various constraints as a sat (satisfiability) problem and
# infer effects of different policies on course allotment and choices. studied relative
# efficiency of various heuristics modeled on different solvers like minisat and
# glucose.
# iit bombay hospital digitization java mysql
# created a complete web application in java that could handle operations on
# relational mysql databases to handle various processes of the university hospital.
# simple 2d physics engine c++
# wrote a physics engine for simple round bodies providing a back-end that could
# generate coordinates in real-time with collision, gravity, restitution and custom
# resolution of time.
# social sea php html javascript
# create a lightweight social search engine that shows the results ranked (using page-
# ranking) according to one's peer-group search history and rating.
# Extracted EDUCATION: indian institute of technology, bombay
# mumbai, india
# bachelor of computer science and engineering (with hons.); jun 2010 - may
# 2014
# cgpa 8.6/10
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# You are not running the flash-attention implementation, expect numerical differences.
# Stage: 1
# User Response: dealing with missing values
# [['Can you describe a challenging project where you applied your experience?', '']]
# User []
# step: 1
# ['dealing with missing values']
# Generating response for prompt: You are a job interviewer. Please generate only 1 follow-up question starting with 'Question:' WITHOUT any additional text or answer...just the question.. based on this: dealing with missing values
# Generated Text: You are a job interviewer. Please generate only 1 follow-up question starting with 'Question:' WITHOUT any additional text or answer...just the question.. based on this: dealing with missing values in dataset
#
# Question: How do you typically handle missing values in a dataset during your analysis process?
#
#
# ### Answer:
# What method do you prefer for imputing missing data in your datasets, and can you explain the rationale behind your choice?
# Stage 1: Added follow-up question: Question: How do you typically handle missing values in a dataset during your analysis process?
# Returning recent question: Question: How do you typically handle missing values in a dataset during your analysis process?
# Stage: 2
# User Response: mean imputation
# [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', '']]
# User ['dealing with missing values']
# step2_1
# Generating response for prompt: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#  . Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
# Generated Text: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#  . Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
#
# 1. Can you describe your experience with C++ and its standard library, especially in the context of memory management and template programming?
# 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?
# 3. Could you explain your approach to writing efficient JavaScript code for Node.js applications, and
# Returning recent question: 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?
# Stage: 3
# User Response: In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity.
# [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', ''], ['2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?', '']]
# User ['dealing with missing values', 'mean imputation']
# step3
# Generating response for prompt: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
# Generated Text: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
#
# 1. Can you describe a complex algorithm you implemented in C++ and how you optimized it for performance?
# 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?
# 3. How have you integrated Java with Node.js or other JavaScript environments, and what are the benefits and drawbacks of using
# Returning recent question: 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?
# Stage: 4
# User Response: Using async/await in JavaScript has streamlined handling asynchronous operations by allowing for cleaner, more readable code that resembles synchronous execution. Best practices include consistently using try/catch blocks for error handling and avoiding nested promises by using `await` for sequential operations. For managing callbacks effectively, converting them to promises and leveraging async/await can reduce callback hell and improve code maintainability.
# [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', ''], ['2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?', ''], ["2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?", '']]
# User ['dealing with missing values', 'mean imputation', "In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity."]
# step4
# Generating response for prompt: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
# Generated Text: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
#
# 1. Can you describe a complex project where you applied the async/await pattern in JavaScript, and explain the challenges you faced during implementation?
# 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?
# 3. How do you ensure that the promises used within async/await functions are resolved correctly, and what strategies do you employ to handle errors
# Returning recent question: 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?
# Stage: 5
# User Response: Common pitfalls with async/await include unhandled promise rejections and blocking the event loop with long-running asynchronous operations. To address these, I've implemented comprehensive error handling with try/catch blocks and used `Promise.all` for concurrent operations to improve performance. Additionally, I ensure that async functions are properly awaited and avoid nesting awaits to keep the code clean and efficient.
# [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', ''], ['2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?', ''], ["2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?", ''], ['2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?', '']]
# User ['dealing with missing values', 'mean imputation', "In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity.", 'Using async/await in JavaScript has streamlined handling asynchronous operations by allowing for cleaner, more readable code that resembles synchronous execution. Best practices include consistently using try/catch blocks for error handling and avoiding nested promises by using `await` for sequential operations. For managing callbacks effectively, converting them to promises and leveraging async/await can reduce callback hell and improve code maintainability.']
# step5
# Generating response for prompt: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
# Generated Text: Generate 1 interview questions based on the following skills: languages
# c++ c\# javascript java c
# technologies
# nodejs uwp win32
#   not this question 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?. Please provide only the questions focused on the subject's bookish knowledge, with no headings or additional text.
# 1. Can you explain the differences between synchronous and asynchronous programming in C++, C#, and Java, and provide examples of situations where each would be preferred?
# 2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java? Can you provide code snippets and examples from your past projects to illustrate your approach?
# 3. What are some common pitfalls when working with promises and async/
# Returning recent question: 2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java?
# Stage: 6
# User Response: In C++, exceptions are managed using `try` and `catch` blocks, while asynchronous operations typically use future and promise mechanisms to handle errors. In C#, async/await leverages `try/catch` blocks to handle exceptions in asynchronous methods. Java uses `try/catch` blocks with `CompletableFuture` or `Future` for managing exceptions in asynchronous code, ensuring that errors are properly propagated and handled.
# [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', ''], ['2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?', ''], ["2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?", ''], ['2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?', ''], ['2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java?', '']]
# User ['dealing with missing values', 'mean imputation', "In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity.", 'Using async/await in JavaScript has streamlined handling asynchronous operations by allowing for cleaner, more readable code that resembles synchronous execution. Best practices include consistently using try/catch blocks for error handling and avoiding nested promises by using `await` for sequential operations. For managing callbacks effectively, converting them to promises and leveraging async/await can reduce callback hell and improve code maintainability.', "Common pitfalls with async/await include unhandled promise rejections and blocking the event loop with long-running asynchronous operations. To address these, I've implemented comprehensive error handling with try/catch blocks and used `Promise.all` for concurrent operations to improve performance. Additionally, I ensure that async functions are properly awaited and avoid nesting awaits to keep the code clean and efficient."]
# Stage 6: Adding user responses and updating stage...
# user response1 ['dealing with missing values', 'mean imputation', "In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity.", 'Using async/await in JavaScript has streamlined handling asynchronous operations by allowing for cleaner, more readable code that resembles synchronous execution. Best practices include consistently using try/catch blocks for error handling and avoiding nested promises by using `await` for sequential operations. For managing callbacks effectively, converting them to promises and leveraging async/await can reduce callback hell and improve code maintainability.', "Common pitfalls with async/await include unhandled promise rejections and blocking the event loop with long-running asynchronous operations. To address these, I've implemented comprehensive error handling with try/catch blocks and used `Promise.all` for concurrent operations to improve performance. Additionally, I ensure that async functions are properly awaited and avoid nesting awaits to keep the code clean and efficient.", 'In C++, exceptions are managed using `try` and `catch` blocks, while asynchronous operations typically use future and promise mechanisms to handle errors. In C#, async/await leverages `try/catch` blocks to handle exceptions in asynchronous methods. Java uses `try/catch` blocks with `CompletableFuture` or `Future` for managing exceptions in asynchronous code, ensuring that errors are properly propagated and handled.']
# q nd a [['Can you describe a challenging project where you applied your experience?', ''], ['Question: How do you typically handle missing values in a dataset during your analysis process?', ''], ['2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?', ''], ["2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?", ''], ['2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?', ''], ['2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java?', '']]
# user response2 ['dealing with missing values', 'mean imputation', "In developing UWP applications with C#, I've leveraged the language's strong integration with the Windows Runtime (WinRT) to create responsive, modern apps. Unique challenges included handling the restricted UWP environment compared to full Win32 access and managing interoperation between UWP and Win32 APIs, which often required careful attention to security and compatibility constraints. Balancing UWP's sandboxed nature with the need for lower-level system calls posed additional complexity.", 'Using async/await in JavaScript has streamlined handling asynchronous operations by allowing for cleaner, more readable code that resembles synchronous execution. Best practices include consistently using try/catch blocks for error handling and avoiding nested promises by using `await` for sequential operations. For managing callbacks effectively, converting them to promises and leveraging async/await can reduce callback hell and improve code maintainability.', "Common pitfalls with async/await include unhandled promise rejections and blocking the event loop with long-running asynchronous operations. To address these, I've implemented comprehensive error handling with try/catch blocks and used `Promise.all` for concurrent operations to improve performance. Additionally, I ensure that async functions are properly awaited and avoid nesting awaits to keep the code clean and efficient.", 'In C++, exceptions are managed using `try` and `catch` blocks, while asynchronous operations typically use future and promise mechanisms to handle errors. In C#, async/await leverages `try/catch` blocks to handle exceptions in asynchronous methods. Java uses `try/catch` blocks with `CompletableFuture` or `Future` for managing exceptions in asynchronous code, ensuring that errors are properly propagated and handled.']
# Generating response for question: 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?
# Model Response: 2. How have you applied your knowledge of C# in developing Windows Universal Platform (UWP) applications, and what are some of the unique challenges you faced when working with Win32 APIs?
#
# # Answer:
#
# As a developer with experience in C# working on Windows Universal Platform (UWP) applications, I've utilized several key principles and concepts to ensure successful project development while also dealing with the challenges of integrating with legacy Win32 APIs. Here are some ways I've applied my knowledge of C# and the unique challenges I've faced:
#
# 1. **Understanding the U
# Generating response for question: 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?
# Model Response: 2. In your experience with JavaScript, how have you utilized async/await patterns to handle asynchronous operations, and what are some best practices you've learned to manage callbacks effectively?
#
# # Answer
#
# Asynchronous programming in JavaScript often involves dealing with operations that take an indeterminate amount of time to complete, such as fetching data from a server, reading files, or making network requests. The `async/await` pattern, which is built on top of JavaScript's Promises, provides a cleaner and more readable way to handle these asynchronous operations compared to traditional callbacks. Here's how I
# Generating response for question: 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?
# Model Response: 2. What are some common pitfalls when using async/await in JavaScript, and how have you addressed these issues in your past projects?
#
# 3. Can you describe a time when you had to refactor a piece of JavaScript code to replace callbacks with async/await, and what benefits did this bring?
#
# 4. Are you familiar with error handling in asynchronous code? Could you explain how you typically manage promise rejections and exceptions when using async/await?
#
# 5. Asynchronous JavaScript is a common topic for interviews. Can you explain how you would educate
# Generating response for question: 2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java?
# ERROR:    Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/queueing.py", line 541, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1928, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1514, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/utils.py", line 833, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 277, in interview_interface
#     recent_question, new_stage, updated_questions_and_answers, updated_user = run_interview(name, skills, experience, user_response, questions_and_answers, user, stage)
#                                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 248, in run_interview
#     sys.exit("Stopping the script")
# SystemExit: Stopping the script
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 700, in lifespan
#     await receive()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/queueing.py", line 541, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1928, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1514, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/utils.py", line 833, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 277, in interview_interface
#     recent_question, new_stage, updated_questions_and_answers, updated_user = run_interview(name, skills, experience, user_response, questions_and_answers, user, stage)
#                                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 248, in run_interview
#     sys.exit("Stopping the script")
# SystemExit: Stopping the script
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 406, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 70, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/middleware/errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/route_utils.py", line 714, in __call__
#     await self.app(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 257, in __call__
#     await wrap(partial(self.listen_for_disconnect, receive))
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 253, in wrap
#     await func()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 230, in listen_for_disconnect
#     message = await receive()
#               ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 534, in receive
#     await self.message_event.wait()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/locks.py", line 213, in wait
#     await fut
# asyncio.exceptions.CancelledError
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/queueing.py", line 541, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1928, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/blocks.py", line 1514, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/utils.py", line 833, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 277, in interview_interface
#     recent_question, new_stage, updated_questions_and_answers, updated_user = run_interview(name, skills, experience, user_response, questions_and_answers, user, stage)
#                                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_55039/2367081628.py", line 248, in run_interview
#     sys.exit("Stopping the script")
# SystemExit: Stopping the script
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 406, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 70, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/middleware/errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/sayantan/.local/lib/python3.11/site-packages/gradio/route_utils.py", line 714, in __call__
#     await self.app(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 257, in __call__
#     await wrap(partial(self.listen_for_disconnect, receive))
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 253, in wrap
#     await func()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/starlette/responses.py", line 230, in listen_for_disconnect
#     message = await receive()
#               ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 534, in receive
#     await self.message_event.wait()
#   File "/root/miniconda3/envs/abhishek/lib/python3.11/asyncio/locks.py", line 213, in wait
#     await fut
# asyncio.exceptions.CancelledError
# Model Response: 2. How do you handle exceptions and error handling when using async/await in C++, C#, and Java?
#
# # Answer
#
# When using async/await in C++, C#, and Java, handling exceptions and errors is critical to ensure robustness and proper error handling in asynchronous operations. Here's how you can handle exceptions and errors in each of these languages:
#
# ### C++
#
# C++ doesn't have built-in support for async/await like C# or Java, but you can achieve similar behavior using libraries like
# Similarity score for row 2: 35.84%
# Similarity score for row 3: 24.61%
# Similarity score for row 4: 23.15%
# Similarity score for row 5: 37.85%
# DataFrame saved to CSV.
# Exitting
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://e38af6ca49e6b18dea.gradio.live
